# %%
import os
import json
import glob
from typing import Dict
import pandas as pd

# %%
csv_cols = ["video_id", "category_id", "views", "likes" , "dislikes", "comment_count",
            "trending_date", "comments_disabled", "ratings_disabled"]
ytdata_cols = csv_cols + ["country", "category"]
data_dir = "src/"

# %%
original_directory = os.getcwd()
try:
    os.chdir(data_dir)
except FileNotFoundError:
    os.chdir("..")
    original_directory = os.getcwd()
    os.chdir(data_dir)

ytdata: pd.DataFrame = pd.DataFrame(columns=ytdata_cols)

for csv_name in glob.glob("*.csv"):
    country: str = csv_name[:2]
    csv_data: pd.DataFrame = pd.read_csv(csv_name, usecols=csv_cols)
    csv_data["country"] = country

    with open(f"{country}_category_id.json", "r") as json_file:
        json_data = json.load(json_file)

    category_dict: Dict[int, str] = {}
    for video_category in json_data['items']:
        category_dict[int(video_category['id'])] = video_category['snippet']['title']
    if 29 not in category_dict:
        category_dict[29] = "Nonprofits & Activism"
        
    csv_data["category"] = csv_data["category_id"].apply(lambda x: category_dict[x])

    ytdata = pd.concat([ytdata, csv_data])

del country, csv_data, csv_name, json_file, json_data, video_category, category_dict

os.chdir(original_directory)
del original_directory

# %%
ytdata = ytdata.loc[(ytdata["video_id"] != "#NAME?") &
                    (ytdata["comments_disabled"] == False) &
                    (ytdata["ratings_disabled"] == False)]
# ytdata.set_index(pd.RangeIndex(start=0, stop=ytdata.shape[0], step=1), inplace=True)

# %%
ytdata.head(10)
# Out:
#        video_id category_id    views  likes dislikes comment_count  \
# 0   SbOwzAl9ZfQ          24   310130   4182      361          1836
# 1   klOV6Xh-DnI          22   104972    271      174           369
# 2   6L2ZF7Qzsbk          25   136064  10105      266           607
# 3   hcY52MFWMDM          25    96153    378      171           208
# 4   _OXDcGPVAa4          26   499965  57781      681          7428
# 5   Q9kK6NWZR1U          10   129645    506       67           239
# 6   c9VTD3n_IDs          22    75197   2277       69           164
# 8   uijjYNtl_UM          24   371110  20155      912           766
# 9   cOJ68MQm2ac          24  1111314  83582     2194          9106
# 10  rZZEeeAVgog          23   471516  23279      270           494
#
#    trending_date comments_disabled ratings_disabled country         category
# 0       17.14.11             False            False      MX    Entertainment
# 1       17.14.11             False            False      MX   People & Blogs
# 2       17.14.11             False            False      MX  News & Politics
# 3       17.14.11             False            False      MX  News & Politics
# 4       17.14.11             False            False      MX    Howto & Style
# 5       17.14.11             False            False      MX            Music
# 6       17.14.11             False            False      MX   People & Blogs
# 8       17.14.11             False            False      MX    Entertainment
# 9       17.14.11             False            False      MX    Entertainment
# 10      17.14.11             False            False      MX           Comedy

# %%
m = 1
for i in c:
#     if i == "#NAME?":
#         continue
    if c[i] >= 35:
        m = c[i]
        print(i, c[i])

# %%
ytdata[ytdata["video_id"] == "DX5_o-mumvE"]
# Out:
#           video_id category_id    views  likes dislikes comment_count  \
# 29131  DX5_o-mumvE          10   441396  17541      935          3406
# 29334  DX5_o-mumvE          10   772730  24251     1450          4660
# 29551  DX5_o-mumvE          10   875544  26201     1606          4936
# 29833  DX5_o-mumvE          10   934163  27392     1716          5127
# 28979  DX5_o-mumvE          10   441396  17541      935          3406
# 29161  DX5_o-mumvE          10   772730  24251     1450          4660
# 29348  DX5_o-mumvE          10   875544  26201     1606          4936
# 29532  DX5_o-mumvE          10   934163  27392     1716          5127
# 29717  DX5_o-mumvE          10   973643  28344     1774          5248
# 29906  DX5_o-mumvE          10  1014222  29410     1846          5396
# 30087  DX5_o-mumvE          10  1044964  30174     1892          5455
# 30278  DX5_o-mumvE          10  1072948  31152     1935          5562
# 30468  DX5_o-mumvE          10  1103499  32530     1970          5669
# 30661  DX5_o-mumvE          10  1141406  34285     2015          5796
# 30855  DX5_o-mumvE          10  1164540  35218     2038          5848
# 31047  DX5_o-mumvE          10  1179196  35744     2050          5893
# 31233  DX5_o-mumvE          10  1192615  36150     2057          5929
# 31406  DX5_o-mumvE          10  1207277  36654     2076          6013
# 31576  DX5_o-mumvE          10  1219253  37044     2085          6063
# 31748  DX5_o-mumvE          10  1228613  37335     2094          6110
# 31911  DX5_o-mumvE          10  1236731  37603     2100          6148
# 32084  DX5_o-mumvE          10  1244912  37862     2105          6159
# 32255  DX5_o-mumvE          10  1252066  38093     2107          6177
# 32429  DX5_o-mumvE          10  1260323  38303     2110          6200
# 32593  DX5_o-mumvE          10  1268921  38518     2118          6230
# 32756  DX5_o-mumvE          10  1277521  38709     2131          6275
# 32922  DX5_o-mumvE          10  1286241  38926     2144          6309
# 33089  DX5_o-mumvE          10  1295298  39158     2156          6333
# 33255  DX5_o-mumvE          10  1301514  39342     2159          6346
# 33426  DX5_o-mumvE          10  1307707  39519     2164          6366
# 33600  DX5_o-mumvE          10  1315751  39725     2175          6379
# 33713  DX5_o-mumvE          10  1320695  39878     2184          6386
# 34077  DX5_o-mumvE          10  1331516  40152     2194          6436
# 34284  DX5_o-mumvE          10  1336800  40314     2197          6444
# 34448  DX5_o-mumvE          10  1341185  40434     2201          6463
# 34613  DX5_o-mumvE          10  1345292  40530     2208          6476
# 34776  DX5_o-mumvE          10  1349219  40629     2210          6480
# 34932  DX5_o-mumvE          10  1353113  40728     2213          6489
# 35084  DX5_o-mumvE          10  1356625  40807     2215          6493
# 29312  DX5_o-mumvE          10   441396  17541      935          3406
#
#       trending_date comments_disabled ratings_disabled country category
# 29131      18.17.04             False            False      CA    Music
# 29334      18.18.04             False            False      CA    Music
# 29551      18.19.04             False            False      CA    Music
# 29833      18.20.04             False            False      CA    Music
# 28979      18.17.04             False            False      GB    Music
# 29161      18.18.04             False            False      GB    Music
# 29348      18.19.04             False            False      GB    Music
# 29532      18.20.04             False            False      GB    Music
# 29717      18.21.04             False            False      GB    Music
# 29906      18.22.04             False            False      GB    Music
# 30087      18.23.04             False            False      GB    Music
# 30278      18.24.04             False            False      GB    Music
# 30468      18.25.04             False            False      GB    Music
# 30661      18.26.04             False            False      GB    Music
# 30855      18.27.04             False            False      GB    Music
# 31047      18.28.04             False            False      GB    Music
# 31233      18.29.04             False            False      GB    Music
# 31406      18.30.04             False            False      GB    Music
# 31576      18.01.05             False            False      GB    Music
# 31748      18.02.05             False            False      GB    Music
# 31911      18.03.05             False            False      GB    Music
# 32084      18.04.05             False            False      GB    Music
# 32255      18.05.05             False            False      GB    Music
# 32429      18.06.05             False            False      GB    Music
# 32593      18.07.05             False            False      GB    Music
# 32756      18.08.05             False            False      GB    Music
# 32922      18.09.05             False            False      GB    Music
# 33089      18.10.05             False            False      GB    Music
# 33255      18.11.05             False            False      GB    Music
# 33426      18.12.05             False            False      GB    Music
# 33600      18.13.05             False            False      GB    Music
# 33713      18.14.05             False            False      GB    Music
# 34077      18.16.05             False            False      GB    Music
# 34284      18.17.05             False            False      GB    Music
# 34448      18.18.05             False            False      GB    Music
# 34613      18.19.05             False            False      GB    Music
# 34776      18.20.05             False            False      GB    Music
# 34932      18.21.05             False            False      GB    Music
# 35084      18.22.05             False            False      GB    Music
# 29312      18.17.04             False            False      DE    Music

# %%
 df["trending_date"].values[15000]

# %%
df.shape[0]

# %%
a = ytdata["video_id"].unique()

# %%
a
# Out:
# array(['SbOwzAl9ZfQ', 'klOV6Xh-DnI', '6L2ZF7Qzsbk', ..., 'Un93Y0bavmw',
#        '6wb8rqDeMlU', 'zSXG5I6Y2fA'], dtype=object)
