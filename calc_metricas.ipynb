# %%
import networkx as nx

import redesoc2020.freeman as fm
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
g = fm.load('rede.gml')

# %%
for n, m in g.edges:
    print(n, m)
# Out:
# eua japao
# eua brasil
# eua coreia do norte
# japao brasil
# japao coreia do norte
# brasil coreia do norte

# %%
g.number_of_nodes()
# Out:
# 4

# %%
g.number_of_edges()
# Out:
# 6

# %%
nx.density(g)
# Out:
# 1.0

# %%
nx.betweenness_centrality(g)
# Out:
# {'eua': 0.0, 'japao': 0.0, 'brasil': 0.0, 'coreia do norte': 0.0}

# %%
nx.closeness_centrality(g)
# Out:
# {'eua': 1.0, 'japao': 1.0, 'brasil': 1.0, 'coreia do norte': 1.0}

# %%
nx.degree_centrality(g)
# Out:
# {'eua': 1.0, 'japao': 1.0, 'brasil': 1.0, 'coreia do norte': 1.0}

# %%
g.set_all_nodes(size=10, labpos='hover')
g.set_all_edges(color=(0, 0, 0, 0.25))

g.draw()
# Out:
# <div>                            <div id="daee22fc-dc75-4efd-9f31-6b8c0e733bff" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daee22fc-dc75-4efd-9f31-6b8c0e733bff")) {                    Plotly.newPlot(                        "daee22fc-dc75-4efd-9f31-6b8c0e733bff",                        [{"hoverinfo": "none", "line": {"color": "rgb(127, 127, 127)", "dash": "solid", "width": 0}, "mode": "lines", "type": "scatter", "x": [-0.19063077360731573, -0.19063077360731573, null, 0, 1, null], "y": [0, 1, null, 0.32732232815779555, 0.32732232815779555, null]}, {"hoverinfo": "none", "line": {"color": "rgba(0, 0, 0, 0.25)", "dash": "solid", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9900969313783549, 0.325201482809115, null, 0.9900969313783549, 0.0, null, 0.9900969313783549, 1.0, null, 0.325201482809115, 0.0, null, 0.325201482809115, 1.0, null, 0.0, 1.0, null], "y": [0.0, 0.18367979513858415, null, 0.0, 0.14732307649932302, null, 0.0, 1.0, null, 0.18367979513858415, 0.14732307649932302, null, 0.18367979513858415, 1.0, null, 0.14732307649932302, 1.0, null]}, {"hoverinfo": "text", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 1}, "size": 10, "symbol": "circle"}, "mode": "markers", "text": [null, null, null, null], "textfont": {"color": "rgb(0, 0, 0)"}, "textposition": "middle center", "type": "scatter", "x": [0.9900969313783549, 0.325201482809115, 0.0, 1.0], "y": [0.0, 0.18367979513858415, 0.14732307649932302, 1.0]}, {"hoverinfo": "none", "mode": "text", "text": [], "textfont": {"color": "rgb(255, 255, 255)"}, "textposition": "middle center", "type": "scatter", "x": [], "y": []}, {"hoverinfo": "none", "mode": "text", "text": [null, null, null, null], "textfont": {"color": "rgb(0, 0, 0)"}, "textposition": "middle center", "type": "scatter", "x": [0.9900969313783549, 0.325201482809115, 0.0, 1.0], "y": [0.0, 0.18367979513858415, 0.14732307649932302, 1.0]}, {"hoverinfo": "none", "mode": "text", "text": [null, null, null, null, null, null], "textfont": {"color": "rgb(0, 0, 0)"}, "textposition": "middle center", "type": "scatter", "x": [0.655500859694363, 0.49388202241007007, 0.9806830001082144, 0.16347840256358348, 0.654667828310533, 0.49392298558898334], "y": [0.06588824537856396, 0.04750145703261685, 0.50047474240136, 0.1393037309770663, 0.6137232975364482, 0.5974449571121276]}, {"hoverinfo": "none", "marker": {"color": "rgba(255, 255, 255, 0)", "line": {"color": "rgba(255, 255, 255, 0)", "width": 0}, "size": 0, "symbol": "circle"}, "mode": "markers", "type": "scatter", "x": [0.5, 0.0, 1.0, 0.5], "y": [0.0, 0.5, 0.5, 1.0]}],                        {"height": 450, "hovermode": "closest", "margin": {"b": 10, "l": 10, "r": 10, "t": 10}, "plot_bgcolor": "rgb(255, 255, 255)", "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8 ...
